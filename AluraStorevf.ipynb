# %% [markdown]
# ##Importación de Librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #Limpieza y Transformación de datos

# %%
tienda['Fecha de Compra'] = pd.to_datetime(tienda['Fecha de Compra'])
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB
# ...

# %%
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'], format='%d/%m/%Y')
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB

# %%
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'], format='%d/%m/%Y')
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB

# %%
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'], format='%d/%m/%Y')
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   datetime64[ns]
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.2+ KB

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ###Números basados en la cantidad de ventas

# %%
len(tienda)
# Out:
# 2359

# %%
len(tienda2)
# Out:
# 2359

# %%
len(tienda3)
# Out:
# 2359

# %%
len(tienda4)
# Out:
# 2358

# %% [markdown]
# ###Números basados en los ingresos monetarios

# %%
ventas_tienda1= float(tienda['Precio'].sum())
total_envios= float(tienda['Costo de envío'].sum())
total_ventas= ventas_tienda1-total_envios
total_ventas
# Out:
# 1089502500.0

# %%
ventas_tienda2= float(tienda2['Precio'].sum())
total_envios2= float(tienda2['Costo de envío'].sum())
total_ventas2= ventas_tienda2-total_envios2
total_ventas2
# Out:
# 1056858400.0

# %%
ventas_tienda3= float(tienda3['Precio'].sum())
total_envios3= float(tienda3['Costo de envío'].sum())
total_ventas3= ventas_tienda3-total_envios3
total_ventas3
# Out:
# 1039503000.0

# %%
ventas_tienda4= float(tienda4['Precio'].sum())
total_envios4= float(tienda4['Costo de envío'].sum())
total_ventas4= ventas_tienda4-total_envios4
total_ventas4
# Out:
# 983058300.0

# %% [markdown]
# ###Diferencia entre la tienda que cuenta con más ingresos y la que cuenta con menos ingresos

# %%
total_ventas-total_ventas4
# Out:
# 106444200.0

# %%
categorias=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos=[total_ventas, total_ventas2, total_ventas3,total_ventas4]

# %%
def labels(x):
  for i in range(len(x)):
     plt.text(i, x[i], f'{x[i]}',ha='center')

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ###Lista basada en la cantidad de ventas

# %%
cantidad_ventas_categoria= tienda['Categoría del Producto'].value_counts()
cantidad_ventas_categoria
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
valores_categorias= []
for i in range(len(cantidad_ventas_categoria)):
  valores_categorias.append(int(cantidad_ventas_categoria[i]))
# Out:
# <ipython-input-19-a39dab6b5e53>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   valores_categorias.append(int(cantidad_ventas_categoria[i]))

# %%
cantidad_ventas_categoria2= tienda2['Categoría del Producto'].value_counts()
cantidad_ventas_categoria2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
cantidad_ventas_categoria3= tienda3['Categoría del Producto'].value_counts()
cantidad_ventas_categoria3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
cantidad_ventas_categoria4= tienda4['Categoría del Producto'].value_counts()
cantidad_ventas_categoria4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
total_categorias= pd.concat([cantidad_ventas_categoria,cantidad_ventas_categoria2, cantidad_ventas_categoria3,cantidad_ventas_categoria4])
total_categorias= total_categorias.groupby(by='Categoría del Producto').sum()
total_categorias= total_categorias.sort_values(ascending=False)
total_categorias
# Out:
# Categoría del Producto
# Muebles                    1886
# Electrónicos               1772
# Juguetes                   1290
# Electrodomésticos          1149
# Deportes y diversión       1113
# Instrumentos musicales      753
# Libros                      742
# Artículos para el hogar     730
# Name: count, dtype: int64

# %%
plt.pie(total_categorias,labels=total_categorias.index,autopct='%1.1f%%', startangle=90)
plt.title('Categorías más vendidas')
plt.show()

# %% [markdown]
# ###Lista basada en los ingresos monetarios

# %%
categoria_tienda = tienda[['Categoría del Producto','Precio']]
categoria_tienda = categoria_tienda.groupby(by='Categoría del Producto')
categoria_tienda= pd.DataFrame(categoria_tienda.sum())
categoria_tienda= categoria_tienda.sort_values(by='Precio', ascending=False)
categoria_tienda
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0

# %%
categoria_tienda2 = tienda2[['Categoría del Producto','Precio']]
categoria_tienda2 = categoria_tienda2.groupby(by='Categoría del Producto')
categoria_tienda2= pd.DataFrame(categoria_tienda2.sum())
categoria_tienda2= categoria_tienda2.sort_values(by='Precio', ascending=False)
categoria_tienda2
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0

# %%
categoria_tienda3 = tienda3[['Categoría del Producto','Precio']]
categoria_tienda3 = categoria_tienda3.groupby(by='Categoría del Producto')
categoria_tienda3= pd.DataFrame(categoria_tienda3.sum())
categoria_tienda3= categoria_tienda3.sort_values(by='Precio', ascending=False)
categoria_tienda3
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# Instrumentos musicales    77380900.0
# Deportes y diversión      35593100.0
# Juguetes                  19401100.0
# Artículos para el hogar   15060000.0
# Libros                     9498700.0

# %%
categoria_tienda4 = tienda4[['Categoría del Producto','Precio']]
categoria_tienda4 = categoria_tienda4.groupby(by='Categoría del Producto')
categoria_tienda4= pd.DataFrame(categoria_tienda4.sum())
categoria_tienda4= categoria_tienda4.sort_values(by='Precio', ascending=False)
categoria_tienda4
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             409476100.0
# Electrodomésticos        283260200.0
# Muebles                  192528900.0
# Instrumentos musicales    75102400.0
# Deportes y diversión      33350100.0
# Juguetes                  20262200.0
# Artículos para el hogar   15074500.0
# Libros                     9321300.0

# %%
total_ventas_categorias= pd.concat([categoria_tienda,categoria_tienda2,categoria_tienda3,categoria_tienda4])
total_ventas_categorias= total_ventas_categorias.groupby(by='Categoría del Producto').sum()
total_ventas_categorias= total_ventas_categorias.sort_values(by='Precio', ascending=False)
total_ventas_categorias
# Out:
#                                Precio
# Categoría del Producto
# Electrónicos             1.660576e+09
# Electrodomésticos        1.324751e+09
# Muebles                  7.576610e+08
# Instrumentos musicales   3.487726e+08
# Deportes y diversión     1.429777e+08
# Juguetes                 7.360440e+07
# Artículos para el hogar  5.757980e+07
# Libros                   3.769610e+07

# %%
plt.figure(figsize=(12,10))
plt.pie(total_ventas_categorias['Precio'],autopct='%1.1f%%', startangle=90, labeldistance=1, textprops={'rotation':45})
plt.legend(total_ventas_categorias.index, loc='best')
plt.title('Ingresos por Categoría')
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_tienda= float(round(tienda['Calificación'].mean(),2))
promedio_tienda
# Out:
# 3.98

# %%
promedio_tienda2= float(round(tienda2['Calificación'].mean(),2))
promedio_tienda2
# Out:
# 4.04

# %%
promedio_tienda3= float(round(tienda3['Calificación'].mean(),2))
promedio_tienda3
# Out:
# 4.05

# %%
promedio_tienda4= float(round(tienda4['Calificación'].mean(),2))
promedio_tienda4
# Out:
# 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ###Lista basada en la cantidad de ventas de cada producto

# %%
productos1= tienda['Producto'].value_counts()
mas_vendidos= pd.DataFrame(productos1.head(5))
menos_vendidos= pd.DataFrame(productos1.tail(5))
top_ventas= pd.concat([mas_vendidos,menos_vendidos])
top_ventas
# Out:
#                              count
# Producto
# Microondas                      60
# TV LED UHD 4K                   60
# Armario                         60
# Secadora de ropa                58
# Mesa de noche                   56
# Ciencia de datos con Python     39
# Pandereta                       36
# Olla de presión                 35
# Auriculares con micrófono       33
# Celular ABXY                    33

# %%
productos2= tienda2['Producto'].value_counts()
mas_vendidos2= pd.DataFrame(productos2.head(5))
menos_vendidos2= pd.DataFrame(productos2.tail(5))
top_ventas2= pd.concat([mas_vendidos2,menos_vendidos2])
top_ventas2
# Out:
#                            count
# Producto
# Iniciando en programación     65
# Microondas                    62
# Batería                       61
# Guitarra acústica             58
# Pandereta                     58
# Auriculares                   37
# Sillón                        35
# Mesa de comedor               34
# Impresora                     34
# Juego de mesa                 32

# %%
productos3= tienda3['Producto'].value_counts()
mas_vendidos3= pd.DataFrame(productos3.head(5))
menos_vendidos3= pd.DataFrame(productos3.tail(5))
top_ventas3= pd.concat([mas_vendidos3,menos_vendidos3])
top_ventas3
# Out:
#                          count
# Producto
# Kit de bancas               57
# Mesa de comedor             56
# Cama king                   56
# Set de ollas                55
# Mesa de noche               55
# Guitarra eléctrica          38
# Set de vasos                36
# Mochila                     36
# Microondas                  36
# Bloques de construcción     35

# %%
productos4= tienda4['Producto'].value_counts()
mas_vendidos4= pd.DataFrame(productos4.head(5))
menos_vendidos4= pd.DataFrame(productos4.tail(5))
top_ventas4= pd.concat([mas_vendidos4,menos_vendidos4])
top_ventas4
# Out:
#                              count
# Producto
# Cama box                        62
# Cubertería                      59
# Dashboards con Power BI         56
# Cama king                       56
# Carrito de control remoto       55
# Refrigerador                    38
# Ciencia de datos con Python     38
# Guitarra acústica               37
# Armario                         34
# Guitarra eléctrica              33

# %%
tiendas= pd.concat([tienda, tienda2, tienda3, tienda4])
tiendas.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      2021-01-16      Pedro Gomez          Bogotá             4
# 1      2022-05-18  Beatriz Morales        Medellín             1
# 2      2021-03-15   Juan Fernandez       Cartagena             1
# 3      2022-05-03   Juan Fernandez            Cali             4
# 4      2020-11-07    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
ventas_productos= pd.DataFrame(tiendas['Producto'])
ventas_productos.value_counts()
# Out:
# Producto
# Mesa de noche                  210
# Microondas                     206
# Carrito de control remoto      206
# Batería                        203
# Cama king                      201
# Modelado predictivo            200
# Secadora de ropa               200
# Set de ollas                   200
# Cama box                       199
# Bloques de construcción        199
# Iphone 15                      198
# Armario                        197
# Pandereta                      197
# Balón de baloncesto            197
# Bicicleta                      196
# Iniciando en programación      195
# Smart TV                       192
# Refrigerador                   191
# Cubertería                     189
# Lavavajillas                   189
# Impresora                      188
# Guitarra acústica              188
# Kit de bancas                  188
# Vaso térmico                   187
# TV LED UHD 4K                  187
# Estufa                         187
# ...

# %% [markdown]
# ###Lista basada en los ingresos monetarios

# %%
ventas= tienda[['Producto','Precio']]
ventas= ventas.groupby(by='Producto').sum()
ventas= ventas.sort_values(by='Precio', ascending=False)
ventas_mayor= ventas.head(5)
ventas_menor= ventas.tail(5)
ingresos_tienda1= pd.concat([ventas_mayor,ventas_menor])
ingresos_tienda1
# Out:
#                          Precio
# Producto
# TV LED UHD 4K       142150200.0
# Refrigerador        112143300.0
# Iphone 15            97902200.0
# Smart TV             67452100.0
# Lavadora de ropa     65783600.0
# Ajedrez de madera     1430600.0
# Set de vasos          1359100.0
# Cubo mágico 8x8        696900.0
# Dinosaurio Rex         688900.0
# Cuerda para saltar     652800.0

# %%
ventas2= tienda2[['Producto','Precio']]
ventas2= ventas2.groupby(by='Producto').sum()
ventas2= ventas2.sort_values(by='Precio', ascending=False)
ventas_mayor2= ventas2.head(5)
ventas_menor2= ventas2.tail(5)
ingresos_tienda2= pd.concat([ventas_mayor2,ventas_menor2])
ingresos_tienda2
# Out:
#                          Precio
# Producto
# Iphone 15           113225800.0
# TV LED UHD 4K       103375000.0
# Refrigerador         97632500.0
# Lavadora de ropa     66762300.0
# Smart TV             61142000.0
# Set de vasos          1542600.0
# Ajedrez de madera     1287700.0
# Cuerda para saltar     856900.0
# Dinosaurio Rex         770300.0
# Cubo mágico 8x8        643600.0

# %%
ventas3= tienda3[['Producto','Precio']]
ventas3= ventas3.groupby(by='Producto').sum()
ventas3= ventas3.sort_values(by='Precio', ascending=False)
ventas_mayor3= ventas3.head(5)
ventas_menor3= ventas3.tail(5)
ingresos_tienda3= pd.concat([ventas_mayor3,ventas_menor3])
ingresos_tienda3
# Out:
#                              Precio
# Producto
# Refrigerador             99889700.0
# TV LED UHD 4K            96669100.0
# Iphone 15                93225700.0
# Smart TV                 78837300.0
# Lavavajillas             64364800.0
# Bloques de construcción   1237200.0
# Set de vasos              1210700.0
# Cuerda para saltar         853800.0
# Dinosaurio Rex             795600.0
# Cubo mágico 8x8            640400.0

# %%
ventas4= tienda4[['Producto','Precio']]
ventas4= ventas4.groupby(by='Producto').sum()
ventas4= ventas4.sort_values(by='Precio', ascending=False)
ventas_mayor4= ventas4.head(5)
ventas_menor4= ventas4.tail(5)
ingresos_tienda4= pd.concat([ventas_mayor4,ventas_menor4])
ingresos_tienda4
# Out:
#                         Precio
# Producto
# Iphone 15           96697500.0
# TV LED UHD 4K       90295300.0
# Smart TV            82790400.0
# Refrigerador        75271900.0
# Tablet ABXY         56723100.0
# Set de vasos         1471800.0
# Ajedrez de madera    1075500.0
# Dinosaurio Rex        858100.0
# Cubo mágico 8x8       748400.0
# Cuerda para saltar    704800.0

# %%
tiendas.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      2021-01-16      Pedro Gomez          Bogotá             4
# 1      2022-05-18  Beatriz Morales        Medellín             1
# 2      2021-03-15   Juan Fernandez       Cartagena             1
# 3      2022-05-03   Juan Fernandez            Cali             4
# 4      2020-11-07    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
ingresos_tiendas= tiendas[['Producto','Precio']]
ingresos_tiendas= ingresos_tiendas.groupby(by='Producto').sum()
ingresos_tiendas= ingresos_tiendas.sort_values(by='Precio', ascending=False)
ingresos_tiendas
# Out:
#                                   Precio
# Producto
# TV LED UHD 4K                432489600.0
# Iphone 15                    401051200.0
# Refrigerador                 384937400.0
# Smart TV                     290221800.0
# Lavadora de ropa             242468600.0
# Lavavajillas                 240536500.0
# Tablet ABXY                  219012800.0
# Secadora de ropa             210238000.0
# Celular ABXY                 157911100.0
# Batería                      147806300.0
# Cama king                    135780400.0
# Estufa                       130871100.0
# Guitarra eléctrica           129404800.0
# Sofá reclinable              123279100.0
# Microondas                   115699500.0
# Cama box                     104097800.0
# Bicicleta                     96487500.0
# Armario                       96245800.0
# Silla de oficina              69099000.0
# Guitarra acústica             58898100.0
# Mesa de noche                 58419500.0
# Impresora                     56227300.0
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envios_tienda1= float(round((tienda['Costo de envío'].mean()),2))
envios_tienda1
# Out:
# 26018.61

# %%
envios_tienda2= float(round((tienda2['Costo de envío'].mean()),2))
envios_tienda2
# Out:
# 25216.24

# %%
envios_tienda3= float(round((tienda3['Costo de envío'].mean()),2))
envios_tienda3
# Out:
# 24805.68

# %%
envios_tienda4= float(round((tienda4['Costo de envío'].mean()),2))
envios_tienda4
# Out:
# 23459.46

# %% [markdown]
# #Reporte

# %% [markdown]
# #Reporte Datos Alura Store: Rendimiento de Tiendas
#
# ##Resumen Ejecutivo:
#
# Este reporte representa un análisis detallado de las cuatro tiendas con las que cuenta el señor Juan, en este reporte se verán reflejados tanto los ingresos, como la calificación dada a las tiendas por los clientes. El fin de este reporte es llegar a la conclusión sobre cuál tienda es la que debe vender el señor Juan y el por qué, claro está, la conclusión estará respaldado por datos, gráficas, comparaciones, entre otros procesos realizados. Los datos estudiados corresponden a:
#
# Ingresos totales
# Ventas por categorías
# Ventas por productos
# Calificación de los clientes
# Valor de los envíos
#
# Este análisis ofrece recomendaciones prácticas para tomar decisiones más confiables.
#
# ##Introducción
#
# El propósito de este estudio es responder a las preguntas:
#
# ###¿Qué tienda se debe vender? y ¿por qué?
#
# Para esto se realizaron diferentes recopilaciones y comparaciones de los datos, además se hicieron distintos tipos de gráficos para respaldar la información, todo para encontrar insights valiosos que nos den pistas para llegar a una decisión acertada.
#
# ##Datos y Metodología
#
# Los datos incluyen: Producto, Categoría del Producto, Precio, Costo del Envío, Fecha de Compra, Vendedor, Lugar de Compra, Calificación, Método de Pago, Cantidad de Cuotas y Coordenadas.
#
# Composición y Descomposición de datos: Se agruparon los datos de cada tienda para realizar comparaciones entre ellas, a la vez se realizó una descomposición de cada una de las tablas con el fin de agrupar los datos en diferentes subsets correspondientes al interés y el desarrollo del estudio.
#
# Graficación: Se realiza la representación gráfica de las tablas y los datos que requieren de mayor entendimiento y atención debido a su importancia.
#
#
#
#
# ##Análisis y Resultados:
#
# Análisis por cantidad de ventas:
#
# Por medio de este proceso se halló primero la cantidad de ventas de cada una de las tiendas, las cuales se van a presentar en este momento:
#
# Tienda 1: 2359 ventas
# Tienda 2: 2359 ventas
# Tienda 3: 2359 ventas
# Tienda 4: 2358 ventas
#
# Con esto podemos llegar a la conclusión de que todas las tiendas han presentado una cantidad de ventas significativamente similar, por ende, este aspecto no será un factor decisivo al momento de tomar una decisión.
#
#
# Análisis por ingresos percibidos:
#
# Se realizó un análisis y comparación de los ingresos registrados de cada una de las tiendas y los resultados son los siguientes:
#
# Tienda 1: 1'089.502.500 COP
# Tienda 2: 1'056.858.400 COP
# Tienda 3: 1'039.503.000 COP
# Tienda 4: 983.058.300 COP
#
# Con esto concluímos que la tienda que más ingresos registra es la tienda 1(1'089.502.500 COP), mientras que la que menos genera es la tienda 4 (983.058.300 COP), la diferencia entre la tienda 1 y la tienda 4 es de 106.444.200 COP.
#
# Nota: A los ingresos de cada tienda se le restó el total de los costos de envío, teniendo en cuenta que dichos costos son asumidos por cada tienda. Como resultado se obtuvo el ingreso neto de cada tienda, el cual fue calculado y presentado previamente.
#
#
#
#
#
# Análisis de ventas e ingresos por categorías:
#
# Se identificaron las categorías que registran más ingresos, y las que registran mayor cantidad de ventas respectivamente, ambos ítems se calificaron por aparte, a continuación vamos a ver las clasificaciones, algunos gráficos que describen cada una de las situaciones y luego un pequeño análisis de lo que se pueden deducir de estos:
#
# 3.1 Clasificación por cantidad de ventas:
#
#
# Categoría del Producto
#        Cantidad de Ventas
# Muebles
# 1886
# Electrónicos
# 1772
# Juguetes
# 1290
# Electrodomésticos
# 1149
# Deportes y diversión
# 1113
# Instrumentos musicales
# 753
# Libros
# 742
# Artículos para el hogar
# 730
#
#
#
#
# 3.2 Clasificación por ingresos percibidos:
#
#
# Categoría del Producto
# Ingresos
# Electrónicos
# 1.660576e+09
# Electrodomésticos
# 1.324751e+09
# Muebles
# 7.576610e+08
# Instrumentos musicales
# 3.487726e+08
# Deportes y diversión
# 1.429777e+08
# Juguetes
# 7.360440e+07
# Artículos para el hogar
# 5.757980e+07
# Libros
# 3.769610e+07
#
#
#
# Calificación Promedio:
#
# Se evaluaron las calificaciones de cada tienda y luego se promediaron para mostrar un valor aproximado, a continuación cada uno de los resultados:
#
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.0
#
# Nota: Todas las tiendas cuentan con una cantidad similar de votos.
#
# Productos más y menos vendidos:
#
# Por motivos de eficiencia en este caso sólo seleccionamos 5 los productos más vendidos. A continuación se presentará la respectiva tabla:
#
# 5.1 Productos con más cantidad de ventas:
#
# Producto
# Cantidad de Ventas
# Mesa de noche
# 210
# Microondas
# 206
# Carrito de control remoto
# 206
# Batería
# 203
# Cama king
# 201
#
#
#
# 5.2 Productos con más ingresos percibidos:
#
#
# Producto
# Ingresos
# TV LED UHD 4K
# 432489600.0
# Iphone 15
# 401051200.0
# Refrigerador
# 384937400.0
# Smart TV
# 290221800.0
# Lavadora de ropa
# 242468600.0
#
#
# Costos de envío:
#
# A continuación se realizó un análisis donde se tomaron los registros de cada tienda y se promediaron para tener una idea aproximada de cuánto gasta cada tienda en costos de envío, a continuación las cifras:
#
# Tienda 1: 26018.61 COP
# Tienda 2: 25216.24 COP
# Tienda 3: 24805.68 COP
# Tienda 4: 23459.46 COP
#
#
#
#
#
# ##CONCLUSIÓN
#
# Con base a los datos brindados, la tienda que se recomienda vender es la tienda 4, esto debido a que es con gran diferencia la tienda que menos genera, y aunque la diferencia es mínima, también es la que registra una menor cantidad de ventas, a parte, aunque no es la que cuenta con una peor calificación por los clientes, sí es de las peores calificadas en los registr
